# %%
import torch
from models import SimpleNN

epochs = 5
losses = []
model = SimpleNN()
for epoch in range(epochs):
    
    checkpoint = torch.load(f'.\model_checkpoints\mnist_simplenn_weights_epoch{epoch}.pth')
    model.load_state_dict(checkpoint)

# %%
pwd
# Out:
# 'C:\\Users\\genai-yerevan-198\\Projects\\nn_classwork'
